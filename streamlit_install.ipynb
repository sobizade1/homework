# %% [markdown]
# <a href="https://colab.research.google.com/github/sobizade1/homework/blob/main/streamlit_install.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 57.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 36.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.5 MB/s eta 0:00:00
# ...

# %%
# !pip install pyngrok

# %%
#now create an app.py file in file tab
# write your streamlit app in app.py file.
# now create an authentication code from the following lin
# now import your keys into your code
#6 tell ngrok noe initiate your ngrok with your token

# %%
from google.colab import userdata
pyngrok_token = userdata.get('pyngrok_auth_token')

# %%
# !ngrok authtoken 2tXRRmpTgqT2Lv0KEDIvdjKIAsT_6pKQU3c2791VNksG58fS
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
from pyngrok import ngrok
# !streamlit run app.py

public_url = ngrok.connect(addr='8501')
print(public_url)
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://130.211.245.114:8501

# %%
from
