# %% [markdown]
# <a href="https://colab.research.google.com/github/sobizade1/homework/blob/main/python_classes_and_streamlit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Student:
    def __init__(self, name, major, gpa, is_on_probation):
        self.name = name
        self.major = major
        self.gpa = gpa
        self.probation = is_on_probation

    def on_honor_roll(self):
        if self.gpa >= 3.5:
            return True
        else:
            return False

student1 = Student("Jim", "Business", 3.1, False)
student2 = Student("Pam", "Art", 2.5, True)

print(student1.name)
print(student2.on_honor_roll())
# Out:
# Jim
# False

# %% [markdown]
# multiple choice questions

# %%
# import Question class from question.py file
from question import Question

question_prompts = ["What colour are apples?\n(a) Red/Green\n(b) Purple\n(c) Orange\n\n",
                    "What colour are bananas?\n(a) Teal\n(b) Magenta\n(c) Yellow\n\n"]
question = [
          Question(question_prompts[0],"a"),
          Question(question_prompts[1],"c"),
          #Question(question_prompts[2],"b")
      ]
def run_test(questions):
    score = 0
    for question in questions:
        answer = input(question.prompt)
        if answer == question.answer:
            score += 1
    print("You got " + str(score) + "/" + str(len(questions)))
run_test(question)
# Out:
# What colour are apples?
# (a) Red/Green
# (b) Purple
# (c) Orange
#
# b
# What colour are bananas?
# (a) Teal
# (b) Magenta
# (c) Yellow
#
# c
# You got 1/2

# %% [markdown]
# STREAM LIT
# Streamlit is an open-source Python framework specifically designed for data scientists and AI/ML engineers. Here's a breakdown of its key features:
#
# Purpose: It's used to create interactive web applications for data and machine learning.
# Efficiency: It allows you to build and share data apps rapidly, often with only a few lines of code.
# Focus: It is ideal for creating visualizations, dashboards, and other interactive tools to explore and present data.
# Open-Source: It's free to use and modify.
# Data Science Focus: It is well suited to data science and machine learning tasks.
# In the code that you shared, you have a section labeled STREAM LIT at the bottom, which suggests that you are considering or will be using it in your notebook.

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 60.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 75.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import userdata
pyngrok_token = userdata.get('pyngrok_auth_token')
print(pyngrok_token)
# Out:
# 2tXRRmpTgqT2Lv0KEDIvdjKIAsT_6pKQU3c2791VNksG58fS

# %%
# !pip install pyngrok

# %%
# !ngrok authtoken pyngrok_token
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
from pyngrok import ngrok

# !stremlit run app.py &>/dev/null &
public_url = ngrok.connect(addr=8501)
public_url

#run streamlit in the background
# create a tunnel to the streamlit app
# pulic_url = ngrok.connct(adr-8501)
#public_url
# Out:
# ERROR:pyngrok.process.ngrok:t=2025-02-28T07:51:45+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: The authtoken you specified does not look like a proper ngrok tunnel authtoken.\nYour authtoken: pyngrok_token\nInstructions to install your authtoken are on your ngrok dashboard:\nhttps://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_105\r\n"
# ERROR:pyngrok.process.ngrok:t=2025-02-28T07:51:45+0000 lvl=eror msg="session closing" obj=tunnels.session err="authentication failed: The authtoken you specified does not look like a proper ngrok tunnel authtoken.\nYour authtoken: pyngrok_token\nInstructions to install your authtoken are on your ngrok dashboard:\nhttps://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_105\r\n"
# ...
